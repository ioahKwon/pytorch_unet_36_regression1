# %%
# !python3 "/content/drive/MyDrive/codes/pytorch_unet_36_regression/train.py" \
--data_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/checkpoint" \
--log_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/log_dir" \
--result_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/result_dir" \
--task "denoising" \
--opts "random" 30.0
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# TRAIN: EPOCH 0034 / 0100 | BATCH 0026 / 0050 | LOSS 0.0172
# TRAIN: EPOCH 0034 / 0100 | BATCH 0027 / 0050 | LOSS 0.0180
# TRAIN: EPOCH 0034 / 0100 | BATCH 0028 / 0050 | LOSS 0.0177
# TRAIN: EPOCH 0034 / 0100 | BATCH 0029 / 0050 | LOSS 0.0189
# TRAIN: EPOCH 0034 / 0100 | BATCH 0030 / 0050 | LOSS 0.0185
# TRAIN: EPOCH 0034 / 0100 | BATCH 0031 / 0050 | LOSS 0.0182
# TRAIN: EPOCH 0034 / 0100 | BATCH 0032 / 0050 | LOSS 0.0180
# TRAIN: EPOCH 0034 / 0100 | BATCH 0033 / 0050 | LOSS 0.0179
# TRAIN: EPOCH 0034 / 0100 | BATCH 0034 / 0050 | LOSS 0.0190
# TRAIN: EPOCH 0034 / 0100 | BATCH 0035 / 0050 | LOSS 0.0186
# TRAIN: EPOCH 0034 / 0100 | BATCH 0036 / 0050 | LOSS 0.0186
# TRAIN: EPOCH 0034 / 0100 | BATCH 0037 / 0050 | LOSS 0.0185
# TRAIN: EPOCH 0034 / 0100 | BATCH 0038 / 0050 | LOSS 0.0183
# TRAIN: EPOCH 0034 / 0100 | BATCH 0039 / 0050 | LOSS 0.0180
# TRAIN: EPOCH 0034 / 0100 | BATCH 0040 / 0050 | LOSS 0.0177
# ...
