# %% [markdown]
# ## **Inpainting**

# %% [markdown]
# *   **random** sampling
# *   probability **50%**

# %% [markdown]
# **Learning type**
#
# *   plain
# *   residual

# %% [markdown]
# **Network**
#
# *   UNet

# %%
# !python "/content/drive/MyDrive/codes/pytorch_unet_36_regression/train.py" \
--mode "train" \
--data_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/checkpoint/inpainting/plain" \
--log_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/log/inpainting/plain" \
--result_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/result/inpainting/plain" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "plain"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# TRAIN: EPOCH 0034 / 0100 | BATCH 0026 / 0050 | LOSS 0.0136
# TRAIN: EPOCH 0034 / 0100 | BATCH 0027 / 0050 | LOSS 0.0136
# TRAIN: EPOCH 0034 / 0100 | BATCH 0028 / 0050 | LOSS 0.0142
# TRAIN: EPOCH 0034 / 0100 | BATCH 0029 / 0050 | LOSS 0.0144
# TRAIN: EPOCH 0034 / 0100 | BATCH 0030 / 0050 | LOSS 0.0141
# TRAIN: EPOCH 0034 / 0100 | BATCH 0031 / 0050 | LOSS 0.0143
# TRAIN: EPOCH 0034 / 0100 | BATCH 0032 / 0050 | LOSS 0.0141
# TRAIN: EPOCH 0034 / 0100 | BATCH 0033 / 0050 | LOSS 0.0140
# TRAIN: EPOCH 0034 / 0100 | BATCH 0034 / 0050 | LOSS 0.0144
# TRAIN: EPOCH 0034 / 0100 | BATCH 0035 / 0050 | LOSS 0.0142
# TRAIN: EPOCH 0034 / 0100 | BATCH 0036 / 0050 | LOSS 0.0144
# TRAIN: EPOCH 0034 / 0100 | BATCH 0037 / 0050 | LOSS 0.0142
# TRAIN: EPOCH 0034 / 0100 | BATCH 0038 / 0050 | LOSS 0.0144
# TRAIN: EPOCH 0034 / 0100 | BATCH 0039 / 0050 | LOSS 0.0144
# TRAIN: EPOCH 0034 / 0100 | BATCH 0040 / 0050 | LOSS 0.0143
# ...

# %%
# !python "/content/drive/MyDrive/codes/pytorch_unet_36_regression/train.py" \
--mode "train" \
--data_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/checkpoint/inpainting/residual" \
--log_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/log/inpainting/residual" \
--result_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/result/inpainting/residual" \
--network "unet" \
--task "inpainting" \
--opts "random" 0.5 \
--learning_type "residual"

# %% [markdown]
# ## **Denoising**

# %% [markdown]
# *   **random** noise
# *   sigma **30.0**

# %% [markdown]
# **Learning type**
#
# *   plain
# *   residual

# %% [markdown]
# **Network**
#
# *   UNet

# %%
# !python "/content/drive/MyDrive/codes/pytorch_unet_36_regression/train.py" \
--mode "train" \
--data_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/checkpoint/denoising/plain" \
--log_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/log/denoising/plain" \
--result_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/result/denoising/plain" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "plain"

# %%
# !python "/content/drive/MyDrive/codes/pytorch_unet_36_regression/train.py" \
--mode "train" \
--data_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/checkpoint/denoising/residual" \
--log_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/log/denoising/residual" \
--result_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/result/denoising/residual" \
--network "unet" \
--task "denoising" \
--opts "random" 30.0 \
--learning_type "residual"

# %% [markdown]
# ## **Super resolution**

# %% [markdown]
# *   **bilinear** interpolation
# *   **x4** downsampling

# %% [markdown]
# **Learning type**
#
# *   plain
# *   residual

# %% [markdown]
# **Network**
#
# *   UNet

# %%
# !python "/content/drive/MyDrive/codes/pytorch_unet_36_regression/train.py" \
--mode "train" \
--data_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/checkpoint/super_resolution/plain" \
--log_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/log/super_resolution/plain" \
--result_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/result/super_resolution/plain" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "plain"

# %%
# !python "/content/drive/MyDrive/codes/pytorch_unet_36_regression/train.py" \
--mode "train" \
--data_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/data/BSR/BSDS500/data/images" \
--ckpt_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/checkpoint/super_resolution/residual" \
--log_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/log/super_resolution/residual" \
--result_dir "/content/drive/MyDrive/codes/pytorch_unet_36_regression/result/super_resolution/residual" \
--network "unet" \
--task "super_resolution" \
--opts "bilinear" 4.0 \
--learning_type "residual"
